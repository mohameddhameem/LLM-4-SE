# %% [markdown]
# # load code text

# %%
from datasets import load_dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the CoDET-M4 dataset
dataset = load_dataset("DaniilOr/CoDET-M4")

# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
python_dataset = dataset['train'].filter(lambda x: x['language'] == 'python')

# %%
import random

# Get unique models from the dataset (filtering out NoneType first)
# Some rows might have None for 'model', we want to ignore them or handle them.
all_models = [m for m in python_dataset['model'] if m is not None]
unique_models = sorted(list(set(all_models)))
print(f"Found {len(unique_models)} unique models: {unique_models}")

selected_indices = []

# Select 5 samples for each model
for model in unique_models:
    # We must ensure we match indices in the original python_dataset
    # enumerate(python_dataset['model']) gives global indices within python_dataset
    model_indices = [
        i for i, m in enumerate(python_dataset['model']) 
        if m == model
    ]
    
    # Sample 5, or all if less than 5
    count = min(5, len(model_indices))
    features = random.sample(model_indices, count)
    selected_indices.extend(features)

# Shuffle the combined indices
random.shuffle(selected_indices)

sample_code = python_dataset.select(selected_indices)

print(f"Total samples selected: {len(sample_code)}")
sample_code
# Out:
# Found 6 unique models: ['codellama', 'gpt', 'human', 'llama3.1', 'nxcode', 'qwen1.5']
# Total samples selected: 30
# Dataset({
#     features: ['code', 'language', 'model', 'split', 'target', 'source', 'features', 'cleaned_code', '__index_level_0__'],
#     num_rows: 30
# })

# %%
# text to ast

# %%
import ast

# Initialize lists
valid_indices = []
sample_asts = []

print(f"Original sample size: {len(sample_code)}")
print("Converting sample_code to AST and filtering...")

for idx, example in enumerate(sample_code):
    try:
        # Parse the code content
        tree = ast.parse(example['code'])
        # If successful, keep track
        sample_asts.append(tree)
        valid_indices.append(idx)
    except SyntaxError as e:
        print(f"Skipping example {idx} due to SyntaxError: {e}")
    except Exception as e:
        print(f"Skipping example {idx} due to Error: {e}")

# Filter the dataset to keep only valid examples
if len(valid_indices) < len(sample_code):
    print(f"Filtering out {len(sample_code) - len(valid_indices)} invalid examples.")
    # Assuming sample_code is a HF Dataset, .select() creates a subset
    sample_code = sample_code.select(valid_indices)
else:
    print("All examples are valid.")

print(f"Conversion complete. Retained {len(sample_code)} valid examples and AST objects.")

# Show structure of the first AST as a verification
if sample_asts:
    print(f"\nExample AST structure (Item 0):")
    print(ast.dump(sample_asts[0], indent=2))
# Out:
# Original sample size: 27
# Converting sample_code to AST and filtering...
# All examples are valid.
# Conversion complete. Retained 27 valid examples and AST objects.
#
# Example AST structure (Item 0):
# Module(
#   body=[
#     FunctionDef(
#       name='excavate',
#       args=arguments(
#         posonlyargs=[],
#         args=[
#           arg(arg='dig')],
#         kwonlyargs=[],
#         kw_defaults=[],
#         defaults=[]),
#       body=[
#         Assign(
#           targets=[
#             Name(id='artifacts', ctx=Store())],
#           value=List(elts=[], ctx=Load())),
#         For(
#           target=Name(id='d', ctx=Store()),
#           iter=Name(id='dig', ctx=Load()),
#           body=[
#             For(
#               target=Name(id='a', ctx=Store()),
#               iter=Name(id='artifacts', ctx=Load()),
#               body=[
#                 If(
#                   test=BoolOp(
#                     op=And(),
#                     values=[
#                       Compare(
#                         left=Subscript(
#                           value=Name(id='d', ctx=Load()),
#                           slice=Constant(value=0),
#                           ctx=Load()),
#                         ops=[
#                           GtE()],
#                         comparators=[
#                           Subscript(
#                             value=Subscript(
#                               value=Name(id='a', ctx=Load()),
#                               slice=Constant(value=0),
#                               ctx=Load()),
#                             slice=Constant(value=0),
#                             ctx=Load())]),
#                       Compare(
#                         left=Subscript(
#                           value=Name(id='d', ctx=Load()),
#                           slice=Constant(value=0),
#                           ctx=Load()),
#                         ops=[
#                           LtE()],
#                         comparators=[
#                           Subscript(
#                             value=Subscript(
#                               value=Name(id='a', ctx=Load()),
#                               slice=Constant(value=0),
#                               ctx=Load()),
#                             slice=Constant(value=1),
#                             ctx=Load())]),
#                       Compare(
#                         left=Subscript(
#                           value=Name(id='d', ctx=Load()),
#                           slice=Constant(value=1),
#                           ctx=Load()),
#                         ops=[
#                           GtE()],
#                         comparators=[
#                           Subscript(
#                             value=Subscript(
#                               value=Name(id='a', ctx=Load()),
#                               slice=Constant(value=1),
#                               ctx=Load()),
#                             slice=Constant(value=0),
#                             ctx=Load())]),
#                       Compare(
#                         left=Subscript(
#                           value=Name(id='d', ctx=Load()),
#                           slice=Constant(value=1),
#                           ctx=Load()),
#                         ops=[
#                           LtE()],
#                         comparators=[
#                           Subscript(
#                             value=Subscript(
#                               value=Name(id='a', ctx=Load()),
#                               slice=Constant(value=1),
#                               ctx=Load()),
#                             slice=Constant(value=1),
#                             ctx=Load())])]),
#                   body=[
#                     Expr(
#                       value=Call(
#                         func=Attribute(
#                           value=Name(id='artifacts', ctx=Load()),
#                           attr='remove',
#                           ctx=Load()),
#                         args=[
#                           Name(id='a', ctx=Load())],
#                         keywords=[]))],
#                   orelse=[])],
#               orelse=[])],
#           orelse=[]),
#         Return(
#           value=Call(
#             func=Name(id='len', ctx=Load()),
#             args=[
#               Name(id='artifacts', ctx=Load())],
#             keywords=[]))],
#       decorator_list=[])],
#   type_ignores=[])

# %% [markdown]
# # ast to pyg

# %%
import torch
from torch_geometric.data import Data
import ast

def ast_to_pyg_data(code_str, target_label):
    """
    Convert python code string to PyG Data object via AST.
    """
    try:
        tree = ast.parse(code_str)
    except SyntaxError:
        return None

    node_list = []
    edge_index = [[], []] # [source_nodes, target_nodes]
    edge_attr = [] # Edge text (field name)
    
    # Map node object id to index
    node_to_idx = {}

    def visit(node, parent_idx=None, relation=None):
        nonlocal node_list, edge_index, edge_attr
        
        # Current node index
        curr_idx = len(node_list)
        node_to_idx[id(node)] = curr_idx
        
        # Node features
        node_type = type(node).__name__
        
        node_list.append({
            'type': node_type
        })
        
        # Add edge if parent exists
        if parent_idx is not None:
            edge_index[0].append(parent_idx)
            edge_index[1].append(curr_idx)
            edge_attr.append(relation if relation else "child")
            
        # Traverse children
        for field, value in ast.iter_fields(node):
            if isinstance(value, list):
                for item in value:
                    if isinstance(item, ast.AST):
                        visit(item, curr_idx, field)
            elif isinstance(value, ast.AST):
                visit(value, curr_idx, field)

    visit(tree)

    if not node_list:
        return None
        
    # Convert to PyG Data
    
    data = Data(
        edge_index=torch.tensor(edge_index, dtype=torch.long),
        num_nodes=len(node_list),
        node_texts=[n['type'] for n in node_list],
        edge_texts=edge_attr,
        code=code_str,
        y=target_label
    )
    
    return data

# Convert the sample_code dataset
pyg_dataset = []

print("Converting to PyG Data objects...")
for idx, item in enumerate(sample_code):
    data = ast_to_pyg_data(item['code'], item['model'])
    if data:
        pyg_dataset.append(data)
    else:
        print(f"Skipping item {idx} due to parse error or empty graph.")

print(f"Conversion complete. Created {len(pyg_dataset)} PyG Data objects.")
# Out:
# Converting to PyG Data objects...
# Conversion complete. Created 27 PyG Data objects.

# %% [markdown]
# # adding features by text encoder

# %%
from create_feature import encode_text_graph

# Apply the encoding
# Using 'tiny' model (MiniLM) for efficiency in this demo
try:
    pyg_dataset = encode_text_graph(pyg_dataset, lm_type="tiny")
    
    # Verify the first graph
    if len(pyg_dataset) > 0:
        g = pyg_dataset[0]
        print("\nFeature Generation Complete.")
        print(f"Node Embeddings (x): {g.x.shape if hasattr(g, 'x') and g.x is not None else 'None'}")
        print(f"Edge Embeddings (edge_attr): {g.edge_attr.shape if hasattr(g, 'edge_attr') and g.edge_attr is not None else 'None'}")
except NameError:
    print("Error: pyg_dataset is not defined. Please run the previous cells first.")
except Exception as e:
    print(f"An error occurred during encoding: {e}")
# Out:
# Using device: cuda
# Loading model: sentence-transformers/all-MiniLM-L6-v2
# Encoding features for 27 graphs...
# 100%|██████████| 27/27 [00:08<00:00,  3.25it/s]
# Feature Generation Complete.
# Node Embeddings (x): torch.Size([96, 384])
# Edge Embeddings (edge_attr): torch.Size([95, 384])

# %%
pyg_dataset
# Out:
# [Data(edge_index=[2, 95], y='ai', num_nodes=96, node_texts=[96], edge_texts=[95], code='def excavate(dig):
#      artifacts = []
#      for d in dig:
#          for a in artifacts:
#              if d[0] >= a[0][0] and d[0] <= a[0][1] and d[1] >= a[1][0] and d[1] <= a[1][1]:
#                  artifacts.remove(a)
#      return len(artifacts)', x=[96, 384], edge_attr=[95, 384]),
#  Data(edge_index=[2, 31], y='ai', num_nodes=32, node_texts=[32], edge_texts=[31], code='def sum_of_series(n):
#      s = 0
#      for i in range(1, n+1):
#          s += factorial(i)
#      return s', x=[32, 384], edge_attr=[31, 384]),
#  Data(edge_index=[2, 26], y='ai', num_nodes=27, node_texts=[27], edge_texts=[26], code='class Solution:
#      def removePalindromeSub(self, s: str) -> int:
#          if s == s[::-1]:  # Check if s is a palindrome
#              return 1
#          else:
#              return 2', x=[27, 384], edge_attr=[26, 384]),
#  Data(edge_index=[2, 52], y='ai', num_nodes=53, node_texts=[53], edge_texts=[52], code='def _get_point_rates(self, source, mmin, mmax=np.inf):
#      """
#      Adds the rates for a point source
#
#      :param source:
#          Point source as instance of :class:
#          openquake.hazardlib.source.point.PointSource
#      :param float mmin:
#          Minimum Magnitude
#      :param float mmax:
#          Maximum Magnitude
#      """
#      # Assuming source has a method get_rates that returns a list of rates based on magnitude
#      rates = source.get_rates()
#
#      # Filter the rates based on the provided minimum and maximum magnitude
#      filtered_rates = {mag: rate for mag, rate in rates.items() if mmin <= mag <= mmax}
#
#      return filtered_rates', x=[53, 384], edge_attr=[52, 384]),
#  Data(edge_index=[2, 53], y='ai', num_nodes=54, node_texts=[54], edge_texts=[53], code='def read_plain_int96(file_obj, count):
#      """
#      Read `count` 96-bit ints using the plain encoding.
#
#      Args:
#          file_obj (file): The file object to read from.
#          count (int): The number of 96-bit ints to read.
#
#      Returns:
#          list: A list of 96-bit ints.
#      """
#      data = file_obj.read(count * 12)  # 96-bit int is 12 bytes
#      return [int.from_bytes(data[i * 12:(i + 1) * 12], 'little') for i in range(count)]', x=[54, 384], edge_attr=[53, 384]),
#  Data(edge_index=[2, 86], y='ai', num_nodes=87, node_texts=[87], edge_texts=[86], code='import pandas as pd
#  import numpy as np
#  from sklearn.preprocessing import StandardScaler
#
#  def _standardize_data(model, data, batch_key):
#      # Extracting batch information from the model matrix
#      design = pd.get_dummies(model[batch_key])
#
#      # Standardizing the data per gene using StandardScaler
#      scaler = StandardScaler()
#      s_data = pd.DataFrame(scaler.fit_transform(data), columns=data.columns)
#
#      # Calculating pooled variance per gene
#      var_pooled = np.var(s_data, axis=0)
#
#      # Computing the gene-wise mean
#      stand_mean = np.mean(s_data, axis=0)
#
#      return s_data, design, var_pooled, stand_mean', x=[87, 384], edge_attr=[86, 384]),
#  Data(edge_index=[2, 154], y='ai', num_nodes=155, node_texts=[155], edge_texts=[154], code='def glyph_extents(self, glyphs):
#      x_bearing = float('inf')
#      y_bearing = float('inf')
#      x_max = float('-inf')
#      y_max = float('-inf')
#      x_advance = 0
#      y_advance = 0
#
#      for glyph in glyphs:
#          # Assuming glyph has properties: x_bearing, y_bearing, width, height, x_advance, y_advance
#          x_bearing = min(x_bearing, glyph.x_bearing)
#          y_bearing = min(y_bearing, glyph.y_bearing)
#          x_max = max(x_max, glyph.x_bearing + glyph.width)
#          y_max = max(y_max, glyph.y_bearing + glyph.height)
#          x_advance += glyph.x_advance
#          y_advance += glyph.y_advance
#
#      width = x_max - x_bearing
#      height = y_max - y_bearing
#
#      return (x_bearing, y_bearing, width, height, x_advance, y_advance)', x=[155, 384], edge_attr=[154, 384]),
#  Data(edge_index=[2, 42], y='ai', num_nodes=43, node_texts=[43], edge_texts=[42], code='import numpy as np
#
#  x = np.linspace(-10, 10, 100)
#  poly_values = 3*x**2 + 2*x - 5
#  print(poly_values)', x=[43, 384], edge_attr=[42, 384]),
#  Data(edge_index=[2, 101], y='human', num_nodes=102, node_texts=[102], edge_texts=[101], code='def _get_goroot(self, goids_all, namespace):
#          """Get the top GO for the set of goids_all."""
#          root_goid = self.consts.NAMESPACE2GO[namespace]
#          if root_goid in goids_all:
#              return root_goid
#          root_goids = set()
#          for goid in goids_all:
#              goterm = self.gosubdag.go2obj[goid]
#              if goterm.depth == 0:
#                  root_goids.add(goterm.id)
#          if len(root_goids) == 1:
#              return next(iter(root_goids))
#          raise RuntimeError("UNEXPECTED NUMBER OF ROOTS: {R}".format(R=root_goids))', x=[102, 384], edge_attr=[101, 384]),
#  Data(edge_index=[2, 14], y='ai', num_nodes=15, node_texts=[15], edge_texts=[14], code='class CRCError(Exception):
#      pass
#
#  def validate_crc(msg):
#      """
#      Validate CRC of message.
#
#      :param msg: Byte array with message with CRC.
#      :raise: CRCError.
#      """
#      # Implement CRC validation logic here
#      # Placeholder to raise an exception for demonstration purposes
#      raise CRCError("Invalid CRC")', x=[15, 384], edge_attr=[14, 384]),
#  Data(edge_index=[2, 27], y='ai', num_nodes=28, node_texts=[28], edge_texts=[27], code='def find(self, text, magicKey=None, sourceCountry=None, bbox=None, location=None, distance=None, outSR=None, category=None, outFields=None, maxLocation=1, forStorage=False):
#      """
#      The find operation geocodes one location per request; the input
#      address is specified in a single parameter.
#
#      Inputs:
#         text - Specifies the location to be geocoded. This can be a
#          street address, place name, postal code, or POI.
#         magicKey - The find operation retrieves results quicker when you
#          pass in valid text and magicKey values than when you don't pass
#          in magicKey. However, to get these advantages, you need to make
#          a prior request to suggest, which provides a magicKey. This may
#          or may not be relevant to your workflow.
#         sourceCountry - A value representing the country. Providing this
#          value increases geocoding speed. Acceptable values include the
#          full country name in English or the official language of the
#          country, the ISO 3166-1 2-digit country code, or the
#          ISO 3166-1 3-digit country code.
#         bbox - A set of bounding box coordinates that limit the search
#          area to a specific region. This is especially useful for
#          applications in which a user will search for places and
#          addresses only within the current map extent.
#         location - Defines an origin point location that is used with
#          the distance parameter to sort geocoding candidates based upon
#          their proximity to the location. The distance parameter
#          specifies the radial distance from the location in meters. The
#          priority of candidates within this radius is boosted relative
#          to those outside the radius.
#         distance - Specifies the radius of an area around a point
#          location which is used to boost the rank of geocoding
#          candidates so that candidates closest to the location are
#          returned first. The distance value is in meters.
#         outSR - The spatial reference of the x/y coordinates returned by
#          a geocode request. This is useful for applications using a map
#          with a spatial reference different than that of the geocode
#          service.
#         category - A place or address type which can be used to filter
#          find results. The parameter supports input of single category
#          values or multiple comma-separated values. The category
#          parameter can be passed in a request with or without the text
#          parameter.
#         outFields - The list of fields to be returned in the response.
#         maxLocation - The maximum number of locations to be returned by
#          a search, up to the maximum number allowed by the service. If
#          not specified, then one location will be returned.
#         forStorage - Specifies whether the results of the operation will
#          be persisted. The default value is false, which indicates the
#          results of the operation can't be stored, but they can be
#          temporarily displayed on a map for instance. If you store the
#          results, in a database for example, you need to set this
#          parameter to true.
#      """
#      # Implementation of geocoding logic goes here
#      pass', x=[28, 384], edge_attr=[27, 384]),
#  Data(edge_index=[2, 129], y='ai', num_nodes=130, node_texts=[130], edge_texts=[129], code='def smallestDistancePair(nums, k):
#      nums.sort()
#      left, right = 0, nums[-1] - nums[0]
#      while left < right:
#          mid = (left + right) // 2
#          count = sum(1 for i in range(len(nums)) for j in range(i+1, len(nums)) if nums[j] - nums[i] <= mid)
#          if count >= k:
#              right = mid
#          else:
#              left = mid + 1
#      return left', x=[130, 384], edge_attr=[129, 384]),
#  Data(edge_index=[2, 85], y='ai', num_nodes=86, node_texts=[86], edge_texts=[85], code='st=input("Enter Student Name: ")
#  stScore=input("Enter Student Score: ")
#  lst=[]
#  lst.append((st,stScore))
#
#  for l in lst:
#    if stScore >= 90:
#      print("A")
#    elif stScore >= 80:
#      print("B")
#    elif stScore >= 70:
#      print("C")
#    elif stScore >= 60:
#      print("D")
#    else:
#      print("F")', x=[86, 384], edge_attr=[85, 384]),
#  Data(edge_index=[2, 36], y='ai', num_nodes=37, node_texts=[37], edge_texts=[36], code='def is_binary_string(string):
#      if len(string) == 0:
#          return False
#
#      for char in string:
#          if char!= '0' and char!= '1':
#              return False
#
#      return True', x=[37, 384], edge_attr=[36, 384]),
#  Data(edge_index=[2, 526], y='human', num_nodes=527, node_texts=[527], edge_texts=[526], code='import sys
#
#  input=sys.stdin.buffer.readline
#
#  for _ in range(int(input())):
#
#    n, d12,d23,d13 = map(int,input().split())
#
#    su = d12+d13+d23
#
#    if su%2:
#
#      print("NO")
#
#      continue
#
#    su//=2
#
#    r1=su-d23
#
#    r2=su-d13
#
#    r3=su-d12
#
#    if r1<0 or r2 <0 or r3<0 or r1+r2+r3+1>n:
#
#      print("NO")
#
#      continue
#
#    rl = [r1,r2,r3]
#
#    d=dict()
#
#    for i, ri in enumerate(rl):
#
#      if ri==0:
#
#        d[1]=i+1
#
#        d[i+1]=1
#
#        rl[0],rl[i]=rl[i],rl[0]
#
#    r1,r2,r3=rl
#
#    r=1
#
#    mx=4
#
#    l1 = [1]+[mx+i for i in range(r1)]
#
#    mx=max([1,2,3]+l1)+1
#
#    l2 = [2]+[mx+i for i in range(r2-1)]+[l1[-1]]
#
#    mx=max([1,2,3]+l1+l2)+1
#
#    l3 = [3]+[mx+i for i in range(r3-1)]+[l1[-1]]
#
#    mx=max([1,2,3]+l1+l2+l3)+1
#
#    t = [1]+[mx+i for i in range(n-mx+1)]
#
#    print("YES")
#
#    for (i,j) in sum((list(zip(l,l[1:])) for l in [l1,l2,l3,t]),[]):
#
#      if i in d:
#
#        i = d[i]
#
#      if j in d:
#
#        j = d[j]
#
#      print(i,j)', x=[527, 384], edge_attr=[526, 384]),
#  Data(edge_index=[2, 41], y='ai', num_nodes=42, node_texts=[42], edge_texts=[41], code='def harmonic_sum(n):
#      return sum(1/i for i in range(1, n))
#
#  n = int(input("Enter a number: "))
#  print(harmonic_sum(n))', x=[42, 384], edge_attr=[41, 384]),
#  Data(edge_index=[2, 318], y='ai', num_nodes=319, node_texts=[319], edge_texts=[318], code='import random
#  from typing import List, Optional, Tuple
#
#  def split_recursive(
#      depth: int,
#      min_width: int,
#      min_height: int,
#      max_horizontal_ratio: float,
#      max_vertical_ratio: float,
#      seed: Optional[random.Random] = None
#  ) -> List[Tuple[int, int, int, int]]:
#
#      if seed is None:
#          seed = random.Random()
#
#      def split(x: int, y: int, width: int, height: int, current_depth: int) -> List[Tuple[int, int, int, int]]:
#          if current_depth >= depth or width <= min_width or height <= min_height:
#              return [(x, y, width, height)]
#
#          if width > height:
#              ratio = seed.uniform(1 / max_horizontal_ratio, max_horizontal_ratio)
#              split_width = int(width * ratio)
#              left_part = split(x, y, split_width, height, current_depth + 1)
#              right_part = split(x + split_width, y, width - split_width, height, current_depth + 1)
#              return left_part + right_part
#          else:
#              ratio = seed.uniform(1 / max_vertical_ratio, max_vertical_ratio)
#              split_height = int(height * ratio)
#              top_part = split(x, y, width, split_height, current_depth + 1)
#              bottom_part = split(x, y + split_height, width, height - split_height, current_depth + 1)
#              return top_part + bottom_part
#
#      return split(0, 0, min_width * 2, min_height * 2, 0)', x=[319, 384], edge_attr=[318, 384]),
#  Data(edge_index=[2, 34], y='ai', num_nodes=35, node_texts=[35], edge_texts=[34], code='def first_duplicate(s):
#      seen = set()
#      for c in s:
#          if c in seen:
#              return c
#          seen.add(c)
#      return None', x=[35, 384], edge_attr=[34, 384]),
#  Data(edge_index=[2, 58], y='ai', num_nodes=59, node_texts=[59], edge_texts=[58], code='class Solution:
#      def firstBadVersion(self, n):
#          start, end = 1, n
#          while start < end:
#              mid = (start+end)//2
#              if isBadVersion(mid):
#                  end = mid
#              else:
#                  start = mid+1
#          return start', x=[59, 384], edge_attr=[58, 384]),
#  Data(edge_index=[2, 162], y='ai', num_nodes=163, node_texts=[163], edge_texts=[162], code='import sys
#
#  def solve(a, k):
#      count = 0
#      for i in range(len(a) - k):
#          if all(a[i + j] * 2**j <= a[i + j + 1] for j in range(k)):
#              count += 1
#      return count
#
#  if __name__ == '__main__':
#      t = int(sys.stdin.readline())
#      for _ in range(t):
#          n, k = list(map(int, sys.stdin.readline().split()))
#          a = list(map(int, sys.stdin.readline().split()))
#          print(solve(a, k))', x=[163, 384], edge_attr=[162, 384]),
#  Data(edge_index=[2, 206], y='ai', num_nodes=207, node_texts=[207], edge_texts=[206], code='def find_opposite_person(t, test_cases):
#      results = []
#      for a, b, c in test_cases:
#          if a > b:
#              a, b = b, a
#          n = b - a + b
#          if n % 2 != 0 or n < max(a, b, c):
#              results.append(-1)
#              continue
#          half = n // 2
#          d = c + half if c <= half else c - half
#          if d > n:
#              results.append(-1)
#          else:
#              results.append(d)
#      return results
#
#  # Reading input
#  t = int(input().strip())
#  test_cases = [tuple(map(int, input().strip().split())) for _ in range(t)]
#  results = find_opposite_person(t, test_cases)
#
#  # Output results
#  for result in results:
#      print(result)', x=[207, 384], edge_attr=[206, 384]),
#  Data(edge_index=[2, 45], y='human', num_nodes=46, node_texts=[46], edge_texts=[45], code='def get_branching_nodes(self):
#          """
#          Returns all nodes that has an out degree >= 2
#          """
#          nodes = set()
#          for n in self.graph.nodes():
#              if self.graph.out_degree(n) >= 2:
#                  nodes.add(n)
#          return nodes', x=[46, 384], edge_attr=[45, 384]),
#  Data(edge_index=[2, 211], y='human', num_nodes=212, node_texts=[212], edge_texts=[211], code='# python p.py < i.txt > o.txt
#
#
#
#
#
#  import io, os, sys, math
#
#
#
#
#
#  input = lambda : sys.stdin.readline().strip()
#
#
#
#
#
#  def solve():
#
#      n = int(input())
#
#      p = list(map(int, input().split()))
#
#      a = 0
#
#      b = 0
#
#      c = 0
#
#      for i in range(1,n+1):
#
#          if p[i-1] != i and p[i-1] != (n+1)-i:
#
#              c += 1
#
#          else:
#
#              if p[i-1] != i:
#
#                  a += 1
#
#              if p[i-1] != (n+1)-i:
#
#                  b += 1
#
#      if a + c <= b:
#
#          print("First")
#
#      else:
#
#          if b + c < a:
#
#              print("Second")
#
#          else:
#
#              print("Tie")
#
#
#
#
#
#  for _ in range(int(input())):
#
#      solve()
#
#  ', x=[212, 384], edge_attr=[211, 384]),
#  Data(edge_index=[2, 79], y='human', num_nodes=80, node_texts=[80], edge_texts=[79], code='for s in[*open(0)][1:]:n,k=map(int,s.split());print(n-k+k//2,*range(k+1>>1,k),*range(k+1,n+1))', x=[80, 384], edge_attr=[79, 384]),
#  Data(edge_index=[2, 126], y='ai', num_nodes=127, node_texts=[127], edge_texts=[126], code='def sumPrefixScores(words):
#      score_dict = {}
#      for word in words:
#          for i in range(len(word)):
#              prefix = word[:i + 1]
#              if prefix not in score_dict:
#                  score_dict[prefix] = 1
#              else:
#                  score_dict[prefix] += 1
#      prefix_scores = [score_dict[prefix] for prefix in words]
#      return prefix_scores
#
#  # Test case assertion
#  test_words = ["a", "ab", "abc", "cab"]
#  assert sumPrefixScores(test_words) == [1, 2, 3, 2]
#
#  # Additional test case assertion
#  test_words_2 = ["test", "testing", "testcases", "testcase", "tests"]
#  assert sumPrefixScores(test_words_2) == [4, 6, 9, 8, 5]', x=[127, 384], edge_attr=[126, 384]),
#  Data(edge_index=[2, 12], y='ai', num_nodes=13, node_texts=[13], edge_texts=[12], code='def emit(self, rule='pass', stage=None, data={}, delay=None):
#      # Add your implementation here
#      pass  # Placeholder, replace with your implementation
#
#      # The function should return the result of invoking the next stage based on the handling rule
#      # If'stage' is specified, it should invoke the specified stage; otherwise, invoke the default 'pass' stage.
#      # The 'data' parameter is a dictionary containing input data for the stage, and 'delay' is an optional delay before invoking the stage.
#      # Implement your logic here', x=[13, 384], edge_attr=[12, 384]),
#  Data(edge_index=[2, 55], y='ai', num_nodes=56, node_texts=[56], edge_texts=[55], code='def sum_non_zero_groups(lst):
#      return sum(sum(group) for group in ''.join(map(str, lst)).split('0'))
#
#  numbers = [1, 0, 2, 0, 3, 0, 4, 5, 0, 6]
#  print(sum_non_zero_groups(numbers))', x=[56, 384], edge_attr=[55, 384])]

# %% [markdown]
# # pretrain

# %%
import torch
from torch_geometric.loader import DataLoader
from transformers import AutoTokenizer
from CodeCLIP import Pretrain # Assuming the class is named CodeCLIP in codeclip.py
import torch.optim as optim
import os

# Create checkpoint directory
checkpoint_dir = 'checkpoints/CodeClip'
os.makedirs(checkpoint_dir, exist_ok=True)
print(f"Checkpoints will be saved to: {checkpoint_dir}")

# Since our dataset is small (9 items), 128 is larger than the dataset.
batch_size = 128
# Create a DataLoader
loader = DataLoader(pyg_dataset, batch_size=batch_size, shuffle=True)

# Initialize Tokenizer
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")
vocab_size = tokenizer.vocab_size

# Initialize Model
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

model = Pretrain(graph_in_dim=384, text_vocab_size=vocab_size, embed_dim=256).to(device)

optimizer = optim.Adam(model.parameters(), lr=1e-3)

# --- Resume from Checkpoint if exists ---
checkpoint_path = os.path.join(checkpoint_dir, 'checkpoint.pt')
if os.path.exists(checkpoint_path):
    print(f"Found checkpoint at {checkpoint_path}. Loading...")
    model.load_state_dict(torch.load(checkpoint_path))
    print("Checkpoint loaded successfully.")
else:
    print("No checkpoint found. Starting training from scratch.")
# ----------------------------------------

# Dummy training loop
num_epochs = 100

print("Starting training...")
model.train()

for epoch in range(num_epochs):
    total_loss = 0
    # loader yields batches of PyG Data objects
    for batch_idx, data in enumerate(loader):
        data = data.to(device)
        # Tokenize on the fly
        text_inputs = tokenizer(
            data.code, 
            padding=True, 
            truncation=True, 
            max_length=512, 
            return_tensors='pt'
        ).input_ids.to(device)
        
        optimizer.zero_grad()
        
        # Forward pass
        logits_graph, logits_text = model(data, text_inputs)
        
        # Loss
        loss = model.loss(logits_graph, logits_text)
        
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
    avg_loss = total_loss / len(loader)
    print(f"Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}")
    
    # Save checkpoint at the end of each epoch
checkpoint_path = os.path.join(checkpoint_dir, f'checkpoint.pt')
torch.save(model.state_dict(), checkpoint_path)

print(f"Training finished. Last model saved to {checkpoint_path}")
# Out:
# Checkpoints will be saved to: checkpoints/CodeClip
# Using device: cuda
# No checkpoint found. Starting training from scratch.
# Starting training...
# Epoch 1/200, Loss: 3.2961
# Epoch 2/200, Loss: 3.2945
# Epoch 3/200, Loss: 3.2928
# Epoch 4/200, Loss: 3.2909
# Epoch 5/200, Loss: 3.2886
# Epoch 6/200, Loss: 3.2859
# Epoch 7/200, Loss: 3.2827
# Epoch 8/200, Loss: 3.2793
# Epoch 9/200, Loss: 3.2757
# Epoch 10/200, Loss: 3.2720
# Epoch 11/200, Loss: 3.2683
# Epoch 12/200, Loss: 3.2645
# Epoch 13/200, Loss: 3.2607
# Epoch 14/200, Loss: 3.2566
# Epoch 15/200, Loss: 3.2526
# Epoch 16/200, Loss: 3.2487
# Epoch 17/200, Loss: 3.2451
# Epoch 18/200, Loss: 3.2419
# Epoch 19/200, Loss: 3.2389
# Epoch 20/200, Loss: 3.2362
# Epoch 21/200, Loss: 3.2335
# Epoch 22/200, Loss: 3.2310
# Epoch 23/200, Loss: 3.2287
# Epoch 24/200, Loss: 3.2262
# Epoch 25/200, Loss: 3.2239
# Epoch 26/200, Loss: 3.2212
# Epoch 27/200, Loss: 3.2182
# Epoch 28/200, Loss: 3.2147
# Epoch 29/200, Loss: 3.2106
# Epoch 30/200, Loss: 3.2057
# Epoch 31/200, Loss: 3.1999
# Epoch 32/200, Loss: 3.1928
# Epoch 33/200, Loss: 3.1841
# Epoch 34/200, Loss: 3.1728
# Epoch 35/200, Loss: 3.1597
# Epoch 36/200, Loss: 3.1451
# Epoch 37/200, Loss: 3.1295
# Epoch 38/200, Loss: 3.1157
# Epoch 39/200, Loss: 3.1018
# Epoch 40/200, Loss: 3.0837
# Epoch 41/200, Loss: 3.0601
# Epoch 42/200, Loss: 3.0345
# Epoch 43/200, Loss: 3.0039
# Epoch 44/200, Loss: 2.9694
# Epoch 45/200, Loss: 2.9352
# Epoch 46/200, Loss: 2.9133
# Epoch 47/200, Loss: 2.8883
# Epoch 48/200, Loss: 2.8472
# Epoch 49/200, Loss: 2.7965
# Epoch 50/200, Loss: 2.7902
# Epoch 51/200, Loss: 2.7903
# Epoch 52/200, Loss: 2.7382
# Epoch 53/200, Loss: 2.7156
# Epoch 54/200, Loss: 2.7240
# Epoch 55/200, Loss: 2.6701
# Epoch 56/200, Loss: 2.6844
# Epoch 57/200, Loss: 2.6567
# Epoch 58/200, Loss: 2.6258
# Epoch 59/200, Loss: 2.6305
# Epoch 60/200, Loss: 2.5904
# Epoch 61/200, Loss: 2.5921
# Epoch 62/200, Loss: 2.5736
# Epoch 63/200, Loss: 2.5595
# Epoch 64/200, Loss: 2.5532
# Epoch 65/200, Loss: 2.5449
# Epoch 66/200, Loss: 2.5280
# Epoch 67/200, Loss: 2.5275
# Epoch 68/200, Loss: 2.5109
# Epoch 69/200, Loss: 2.5084
# Epoch 70/200, Loss: 2.5003
# Epoch 71/200, Loss: 2.4949
# Epoch 72/200, Loss: 2.4890
# Epoch 73/200, Loss: 2.4853
# Epoch 74/200, Loss: 2.4791
# Epoch 75/200, Loss: 2.4774
# Epoch 76/200, Loss: 2.4696
# Epoch 77/200, Loss: 2.4677
# Epoch 78/200, Loss: 2.4637
# Epoch 79/200, Loss: 2.4596
# Epoch 80/200, Loss: 2.4574
# Epoch 81/200, Loss: 2.4537
# Epoch 82/200, Loss: 2.4503
# Epoch 83/200, Loss: 2.4482
# Epoch 84/200, Loss: 2.4454
# Epoch 85/200, Loss: 2.4425
# Epoch 86/200, Loss: 2.4403
# Epoch 87/200, Loss: 2.4380
# Epoch 88/200, Loss: 2.4353
# Epoch 89/200, Loss: 2.4336
# Epoch 90/200, Loss: 2.4310
# Epoch 91/200, Loss: 2.4292
# Epoch 92/200, Loss: 2.4271
# Epoch 93/200, Loss: 2.4256
# Epoch 94/200, Loss: 2.4237
# Epoch 95/200, Loss: 2.4219
# Epoch 96/200, Loss: 2.4203
# Epoch 97/200, Loss: 2.4196
# Epoch 98/200, Loss: 2.4175
# Epoch 99/200, Loss: 2.4163
# Epoch 100/200, Loss: 2.4147
# Epoch 101/200, Loss: 2.4134
# Epoch 102/200, Loss: 2.4117
# Epoch 103/200, Loss: 2.4107
# Epoch 104/200, Loss: 2.4096
# Epoch 105/200, Loss: 2.4084
# Epoch 106/200, Loss: 2.4071
# Epoch 107/200, Loss: 2.4064
# Epoch 108/200, Loss: 2.4052
# Epoch 109/200, Loss: 2.4044
# Epoch 110/200, Loss: 2.4029
# Epoch 111/200, Loss: 2.4022
# Epoch 112/200, Loss: 2.4014
# Epoch 113/200, Loss: 2.4008
# Epoch 114/200, Loss: 2.3991
# Epoch 115/200, Loss: 2.3983
# Epoch 116/200, Loss: 2.3976
# Epoch 117/200, Loss: 2.3969
# Epoch 118/200, Loss: 2.3956
# Epoch 119/200, Loss: 2.3948
# Epoch 120/200, Loss: 2.3941
# Epoch 121/200, Loss: 2.3932
# Epoch 122/200, Loss: 2.3928
# Epoch 123/200, Loss: 2.3917
# Epoch 124/200, Loss: 2.3908
# Epoch 125/200, Loss: 2.3898
# Epoch 126/200, Loss: 2.3892
# Epoch 127/200, Loss: 2.3886
# Epoch 128/200, Loss: 2.3878
# Epoch 129/200, Loss: 2.3869
# Epoch 130/200, Loss: 2.3856
# Epoch 131/200, Loss: 2.3851
# Epoch 132/200, Loss: 2.3846
# Epoch 133/200, Loss: 2.3842
# Epoch 134/200, Loss: 2.3834
# Epoch 135/200, Loss: 2.3831
# Epoch 136/200, Loss: 2.3822
# Epoch 137/200, Loss: 2.3817
# Epoch 138/200, Loss: 2.3804
# Epoch 139/200, Loss: 2.3794
# Epoch 140/200, Loss: 2.3782
# Epoch 141/200, Loss: 2.3774
# Epoch 142/200, Loss: 2.3768
# Epoch 143/200, Loss: 2.3763
# Epoch 144/200, Loss: 2.3756
# Epoch 145/200, Loss: 2.3746
# Epoch 146/200, Loss: 2.3736
# Epoch 147/200, Loss: 2.3730
# Epoch 148/200, Loss: 2.3723
# Epoch 149/200, Loss: 2.3721
# Epoch 150/200, Loss: 2.3718
# Epoch 151/200, Loss: 2.3719
# Epoch 152/200, Loss: 2.3723
# Epoch 153/200, Loss: 2.3724
# Epoch 154/200, Loss: 2.3727
# Epoch 155/200, Loss: 2.3722
# Epoch 156/200, Loss: 2.3699
# Epoch 157/200, Loss: 2.3668
# Epoch 158/200, Loss: 2.3651
# Epoch 159/200, Loss: 2.3652
# Epoch 160/200, Loss: 2.3662
# Epoch 161/200, Loss: 2.3663
# Epoch 162/200, Loss: 2.3646
# Epoch 163/200, Loss: 2.3621
# Epoch 164/200, Loss: 2.3610
# Epoch 165/200, Loss: 2.3616
# Epoch 166/200, Loss: 2.3617
# Epoch 167/200, Loss: 2.3602
# Epoch 168/200, Loss: 2.3583
# Epoch 169/200, Loss: 2.3574
# Epoch 170/200, Loss: 2.3578
# Epoch 171/200, Loss: 2.3582
# Epoch 172/200, Loss: 2.3573
# Epoch 173/200, Loss: 2.3557
# Epoch 174/200, Loss: 2.3539
# Epoch 175/200, Loss: 2.3536
# Epoch 176/200, Loss: 2.3538
# Epoch 177/200, Loss: 2.3537
# Epoch 178/200, Loss: 2.3527
# Epoch 179/200, Loss: 2.3510
# Epoch 180/200, Loss: 2.3500
# Epoch 181/200, Loss: 2.3499
# Epoch 182/200, Loss: 2.3496
# Epoch 183/200, Loss: 2.3489
# Epoch 184/200, Loss: 2.3476
# Epoch 185/200, Loss: 2.3469
# Epoch 186/200, Loss: 2.3466
# Epoch 187/200, Loss: 2.3463
# Epoch 188/200, Loss: 2.3457
# Epoch 189/200, Loss: 2.3445
# Epoch 190/200, Loss: 2.3436
# Epoch 191/200, Loss: 2.3431
# Epoch 192/200, Loss: 2.3429
# Epoch 193/200, Loss: 2.3427
# Epoch 194/200, Loss: 2.3422
# Epoch 195/200, Loss: 2.3414
# Epoch 196/200, Loss: 2.3403
# Epoch 197/200, Loss: 2.3395
# Epoch 198/200, Loss: 2.3389
# Epoch 199/200, Loss: 2.3385
# Epoch 200/200, Loss: 2.3381
# Training finished. Last model saved to checkpoints/CodeClip/checkpoint.pt

# %%
# Load the model from checkpoint and extract graph embeddings
model.eval()

# Load state dict
# checkpoint_path was defined in the previous cell ('checkpoints/CodeClip/checkpoint.pt')
if os.path.exists(checkpoint_path):
    print(f"Loading checkpoint from {checkpoint_path}")
    model.load_state_dict(torch.load(checkpoint_path))
else:
    print(f"Checkpoint {checkpoint_path} not found. Using current model state.")

graph_embeddings = []
model.to(device)

print("Extracting graph embeddings...")
with torch.no_grad():
    for batch_idx, data in enumerate(loader):
        data = data.to(device)
        features = model.graph_encoder(data.x, data.edge_index, data.edge_attr, data.batch)
        
        # Normalize if needed (CodeCLIP does it in forward, so we probably should too for consistency)
        features = features / features.norm(dim=1, keepdim=True)
        
        graph_embeddings.append(features.cpu())

# Concatenate all embeddings
if graph_embeddings:
    all_graph_embeddings = torch.cat(graph_embeddings, dim=0)
else:
    print("No embeddings extracted.")
# Out:
# Loading checkpoint from checkpoints/CodeClip/checkpoint.pt
# /tmp/ipykernel_1689643/2112133876.py:8: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(checkpoint_path))
# Extracting graph embeddings...

# %%
all_graph_embeddings
# Out:
# tensor([[ 0.1555,  0.0197, -0.0193,  ..., -0.0208,  0.1141,  0.0075],
#         [ 0.0863,  0.0580,  0.0516,  ..., -0.0273,  0.0757,  0.0487],
#         [ 0.1033, -0.0349, -0.1116,  ..., -0.0107,  0.0591, -0.0673],
#         ...,
#         [ 0.1371, -0.0019, -0.1219,  ..., -0.0315,  0.0214,  0.0067],
#         [-0.1206,  0.0649, -0.0052,  ...,  0.0652, -0.1116,  0.0190],
#         [-0.0395, -0.0639,  0.0311,  ..., -0.0267, -0.0113, -0.0487]])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Select the first embedding
embedding_vector = all_graph_embeddings[0, :].numpy()

# Create a bar plot
plt.figure(figsize=(12, 4))
plt.bar(range(len(embedding_vector)), embedding_vector, color='skyblue', width=1.0)
plt.title('Feature Vector Visualization (Item 0)')
plt.xlabel('Dimension Index')
plt.ylabel('Value')
plt.grid(True, alpha=0.3)

# Highlight max and min
max_idx = np.argmax(embedding_vector)
min_idx = np.argmin(embedding_vector)
plt.scatter([max_idx], [embedding_vector[max_idx]], color='red', label='Max', zorder=5)
plt.scatter([min_idx], [embedding_vector[min_idx]], color='green', label='Min', zorder=5)

plt.legend()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
import seaborn as sns

embeddings = all_graph_embeddings.detach().cpu().numpy()
labels = [data.y for data in pyg_dataset]

pca = PCA(n_components=2)
embeddings_2d = pca.fit_transform(embeddings)

plt.figure(figsize=(10, 8))
label_set = list(set(labels))

# Defines a more comprehensive color map
color_map = {
    'human': 'blue', 
    'gpt': 'red',
    'llama3.1': 'orange',
    'codellama': 'green',
    'qwen1.5': 'purple',
    'nxcode': 'cyan'
} 
# Fallback for unknown labels (using a palette)
fallback_colors = sns.color_palette("husl", len(label_set))

for i, label in enumerate(label_set):
    indices = [j for j, l in enumerate(labels) if l == label]
    if not indices: continue
    
    points = embeddings_2d[indices]
    
    # Use color_map if label exists, otherwise use fallback
    color = color_map.get(label, fallback_colors[i])
    
    plt.scatter(points[:, 0], points[:, 1], 
                c=[color], 
                label=label, alpha=0.7, s=100)

plt.title('PCA Visualization of Code Graph Embeddings by Model')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 1. Get embeddings
embeddings = all_graph_embeddings.detach().cpu().numpy()

# 2. Apply Exponential Transformation
embeddings_exp = np.exp(embeddings) 

embeddings_exp = np.exp(embeddings) / np.sum(np.exp(embeddings), axis=1, keepdims=True)

plt.figure(figsize=(15, 6))

# 3. Plot
img = plt.imshow(embeddings_exp, cmap='coolwarm', aspect='auto', interpolation='nearest')

plt.colorbar(img, label='Exponential Activation (exp(x))')
plt.title('Heatmap of Graph Embeddings (Exponential Scaling)')
plt.xlabel('Feature Dimension')
plt.ylabel('Sample Index')

plt.yticks(range(len(embeddings)), labels=[f"Graph {i} ({l})" for i, l in enumerate(labels)])

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

embeddings_np = all_graph_embeddings.detach().cpu().numpy()
labels_list = [data.y for data in pyg_dataset]

sorted_indices = np.argsort(labels_list)
sorted_embeddings = embeddings_np[sorted_indices]
sorted_labels = np.array(labels_list)[sorted_indices]

exp_vals = np.exp(sorted_embeddings - np.max(sorted_embeddings, axis=1, keepdims=True))
embeddings_processed = exp_vals / np.sum(exp_vals, axis=1, keepdims=True)

plt.figure(figsize=(16, 8))

img = plt.imshow(embeddings_processed, cmap='coolwarm', aspect='auto', interpolation='nearest')

for i in range(1, len(sorted_labels)):
    if sorted_labels[i] != sorted_labels[i-1]:
        plt.axhline(y=i-0.5, color='black', linestyle='--', linewidth=1.5, alpha=0.8)

plt.colorbar(img, label='Activation Intensity (Softmax)')
plt.title('Sorted Heatmap of Graph Embeddings (Auto-Grouped)', fontsize=14)
plt.xlabel('Feature Dimension (0-256)', fontsize=12)
plt.ylabel('Samples (Grouped by Label)', fontsize=12)

plt.yticks(
    ticks=range(len(sorted_labels)), 
    labels=[f"{i}: {lbl}" for i, lbl in zip(sorted_indices, sorted_labels)],
    fontsize=8
)

plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Re-calculate sorted embeddings to ensure context (using variables from previous steps)
embeddings_np = all_graph_embeddings.detach().cpu().numpy()
labels_list = [data.y for data in pyg_dataset]

sorted_indices = np.argsort(labels_list)
sorted_embeddings = embeddings_np[sorted_indices]
sorted_labels = np.array(labels_list)[sorted_indices]

# Compute Cosine Similarity Matrix
# Normalize vectors to unit length
norms = np.linalg.norm(sorted_embeddings, axis=1, keepdims=True)
normalized_embeddings = sorted_embeddings / (norms + 1e-8)  # Avoid div by zero

# Compute dot product (NxN similarity matrix)
similarity_matrix = np.dot(normalized_embeddings, normalized_embeddings.T)

# Plot Heatmap
plt.figure(figsize=(10, 8))
# 'viridis' or 'coolwarm' are good choices. 'RdBu_r' is also good for -1 to 1 correlation.
# Since we deal with embeddings, values are likely > 0 if using ReLU, but cosine is -1 to 1.
# Let's use 'viridis' for general similarity or 'Blues'.
img = plt.imshow(similarity_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar(img, label='Cosine Similarity')

# Draw separation lines for groups
transitions = [i for i in range(1, len(sorted_labels)) if sorted_labels[i] != sorted_labels[i-1]]
for t in transitions:
    plt.axhline(y=t-0.5, color='blacK', linestyle='--', linewidth=1, alpha=0.7)
    plt.axvline(x=t-0.5, color='blacK', linestyle='--', linewidth=1, alpha=0.7)

plt.title('Pairwise Similarity Matrix (Sorted by Group)')
plt.xlabel('Samples (Sorted)')
plt.ylabel('Samples (Sorted)')

# Optional: Add group labels on axes
# Calculate center positions for labels
group_starts = [0] + transitions + [len(sorted_labels)]
tick_locs = []
group_names = []
for i in range(len(group_starts)-1):
    start = group_starts[i]
    end = group_starts[i+1]
    tick_locs.append((start + end) / 2)
    group_names.append(sorted_labels[start])

plt.xticks(tick_locs, group_names, rotation=45, ha='right')
plt.yticks(tick_locs, group_names)

plt.tight_layout()
plt.show()
